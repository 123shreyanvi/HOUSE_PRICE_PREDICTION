# %% [markdown]
# # BHARAT INTERN

# %% [markdown]
# # MACHINE LEARNING TASK 1

# %% [markdown]
# # 1. House Price Prediction

# %% [markdown]
# #

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Housing.csv")

# %%
df.head(20)
# Out:
#     No  X1 transaction date  X2 house age  \
# 0    1             2012.917          32.0
# 1    2             2012.917          19.5
# 2    3             2013.583          13.3
# 3    4             2013.500          13.3
# 4    5             2012.833           5.0
# 5    6             2012.667           7.1
# 6    7             2012.667          34.5
# 7    8             2013.417          20.3
# 8    9             2013.500          31.7
# 9   10             2013.417          17.9
# 10  11             2013.083          34.8
# 11  12             2013.333           6.3
# 12  13             2012.917          13.0
# 13  14             2012.667          20.4
# 14  15             2013.500          13.2
# 15  16             2013.583          35.7
# 16  17             2013.250           0.0
# 17  18             2012.750          17.7
# 18  19             2013.417          16.9
# 19  20             2012.667           1.5
#
#     X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                 84.87882                               10
# 1                                306.59470                                9
# 2                                561.98450                                5
# 3                                561.98450                                5
# 4                                390.56840                                5
# 5                               2175.03000                                3
# 6                                623.47310                                7
# 7                                287.60250                                6
# 8                               5512.03800                                1
# 9                               1783.18000                                3
# 10                               405.21340                                1
# 11                                90.45606                                9
# 12                               492.23130                                5
# 13                              2469.64500                                4
# 14                              1164.83800                                4
# 15                               579.20830                                2
# 16                               292.99780                                6
# 17                               350.85150                                1
# 18                               368.13630                                8
# 19                                23.38284                                7
#
#     X5 latitude  X6 longitude  Y house price of unit area
# 0      24.98298     121.54024                        37.9
# 1      24.98034     121.53951                        42.2
# 2      24.98746     121.54391                        47.3
# 3      24.98746     121.54391                        54.8
# 4      24.97937     121.54245                        43.1
# 5      24.96305     121.51254                        32.1
# 6      24.97933     121.53642                        40.3
# 7      24.98042     121.54228                        46.7
# 8      24.95095     121.48458                        18.8
# 9      24.96731     121.51486                        22.1
# 10     24.97349     121.53372                        41.4
# 11     24.97433     121.54310                        58.1
# 12     24.96515     121.53737                        39.3
# 13     24.96108     121.51046                        23.8
# 14     24.99156     121.53406                        34.3
# 15     24.98240     121.54619                        50.5
# 16     24.97744     121.54458                        70.1
# 17     24.97544     121.53119                        37.4
# 18     24.96750     121.54451                        42.3
# 19     24.96772     121.54102                        47.7

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.shape
# Out:
# (414, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
counter = 0
rs,cs = df.shape

df.drop_duplicates(inplace=True)

if df.shape==(rs,cs):
    print('\n\033[1mInference:\033[0m The dataset doesn\'t have any duplicates')
else:
    print(f'\n\033[1mInference:\033[0m Number of duplicates dropped/fixed ---> {rs-df.shape[0]}')
# Out:
# Inference: The dataset doesn't have any duplicates

# %%
from sklearn.preprocessing import LabelEncoder
categ = ['X3 distance to the nearest MRT station',
       'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
       'Y house price of unit area']
le = LabelEncoder()
df[categ] = df[categ].apply(le.fit_transform)

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                       5                               10
# 1                                      59                                9
# 2                                     134                                5
# 3                                     134                                5
# 4                                      90                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0          210           143                         129
# 1          188           132                         162
# 2          225           188                         200
# 3          225           188                         234
# 4          183           167                         170

# %%
df.plot()
# Out:
# <Axes: >

# %%
corr = df.corr()
plt.figure(figsize = (12,7))
sns.heatmap(corr,cmap="coolwarm",annot=True)
# Out:
# <Axes: >

# %%
X = df.drop(['No'],axis=1)
Y = df['No']

# %%
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                         5                               10
# 1                                        59                                9
# 2                                       134                                5
# 3                                       134                                5
# 4                                        90                                5
# ..                                      ...                              ...
# 409                                     245                                0
# 410                                       7                                9
# 411                                      91                                7
# 412                                       8                                5
# 413                                       7                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 0            210           143                         129
# 1            188           132                         162
# 2            225           188                         200
# 3            225           188                         234
# 4            183           167                         170
# ..           ...           ...                         ...
# 409            4            14                          14
# 410          142           181                         214
# 411          180           137                         150
# 412           87           148                         226
# 413          142           181                         261
#
# [414 rows x 7 columns]

# %%
Y
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 409    410
# 410    411
# 411    412
# 412    413
# 413    414
# Name: No, Length: 414, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.3,random_state=45)

# %%
len(X_train),len(X_test)
# Out:
# (289, 125)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
X= df.iloc[:,:-1].values
Y= df.iloc[:,1].values

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_predict = model.predict(X_test)

# %%
Y_predict
# Out:
# array([217.64129037, 231.43264636, 165.40898617, 247.09589941,
#        205.76271061, 201.79466859, 187.28652467, 177.40128548,
#        205.37390453, 212.65287334, 187.69578109, 188.28083438,
#        206.94231689, 192.14072017, 198.74867724, 196.35912233,
#        172.08666033, 179.7906557 , 218.75237328, 186.2941101 ,
#        229.75707025, 216.96570476, 211.64083624, 223.25007592,
#        124.00176982, 210.12793512, 196.11434714, 214.78805712,
#        195.87900488, 172.40330833, 175.25570329, 219.71570145,
#        207.11467184, 190.87043847, 219.04694605, 206.19349916,
#        196.69365757, 186.82175417, 230.70909777, 192.07689055,
#        183.6740198 , 202.22430364, 199.16705632, 196.78494054,
#        198.42409355, 228.39187833, 202.50067667, 202.07910914,
#        208.68115616, 213.48089088, 199.19161701, 190.99951842,
#        198.89955305, 194.99870279, 240.85406373, 222.17948245,
#        227.08004978, 165.87321573, 219.69513881, 209.57350959,
#        180.23857309, 180.83783969, 193.79647125, 255.15512798,
#        198.10866241, 210.52508081, 196.90596693, 194.9483389 ,
#        217.17295753, 207.32170125, 195.11538734, 183.88474521,
#        176.9446497 , 162.86180636, 191.98428769, 236.76835475,
#        205.16121625, 199.85681183, 199.16735536, 217.48735978,
#        198.13742713, 200.91466373, 220.60251443, 245.3594316 ,
#        229.6601269 , 223.24458553, 205.84008105, 211.00591861,
#        204.42539145, 194.80340923, 221.06994755, 213.23029026,
#        234.12199961, 210.96015533, 197.91723941, 220.85586244,
#        225.51827853, 193.96281876, 243.72876995, 198.24179473,
#        185.02886537, 197.45869114, 193.82917957, 189.21280703,
#        209.55347822, 191.99752797, 204.7396214 , 214.20729459,
#        206.67975212, 232.00812406, 214.45512053, 177.78252823,
#        184.30631866, 199.40574764, 212.62181044, 188.52663847,
#        206.50499016, 137.61624953, 205.12362119, 261.12345238,
#        188.91918424, 205.05541459, 150.6310347 , 196.34520451,
#        204.02587105])

# %%
from sklearn.metrics import r2_score,mean_absolute_error
score  = r2_score(Y_test,Y_predict)
mae = mean_absolute_error(Y_test,Y_predict)

# %%
score
# Out:
# -0.025250890899331857

# %%
mae
# Out:
# 99.94372387484042
